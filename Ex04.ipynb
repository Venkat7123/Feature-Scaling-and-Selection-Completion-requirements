# %% [markdown]
# <a href="https://colab.research.google.com/github/Venkat7123/Feature-Scaling-and-Selection-Completion-requirements/blob/main/Ex04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from scipy import stats
import numpy as np

# %%
df = pd.read_csv('/content/bmi.csv')

# %%
df.head()
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %%
df.dropna()
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %%
max_vals = np.max(np.abs(df[['Height','Weight']]))
max_vals
# Out:
# 199

# %%
df1 = pd.read_csv('/content/bmi.csv')

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
df1[['Height','Weight']] = sc.fit_transform(df1[['Height','Weight']])
df1.head(10)
# Out:
#    Gender    Height    Weight  Index
# 0    Male  0.247939 -0.309117      4
# 1    Male  1.164872 -0.587322      2
# 2  Female  0.920357  0.123647      4
# 3  Female  1.531645 -0.061823      3
# 4    Male -1.280283 -1.391027      3
# 5    Male  1.164872 -0.061823      3
# 6    Male -1.402541 -0.432764      5
# 7    Male -0.974639  0.154559      5
# 8    Male  0.247939 -0.494587      3
# 9  Female -0.057706 -0.092735      4

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[['Height','Weight']] = scaler.fit_transform(df[['Height','Weight']])
df.head(10)
# Out:
#    Gender    Height    Weight  Index
# 0    Male  0.576271  0.418182      4
# 1    Male  0.830508  0.336364      2
# 2  Female  0.762712  0.545455      4
# 3  Female  0.932203  0.490909      3
# 4    Male  0.152542  0.100000      3
# 5    Male  0.830508  0.490909      3
# 6    Male  0.118644  0.381818      5
# 7    Male  0.237288  0.554545      5
# 8    Male  0.576271  0.363636      3
# 9  Female  0.491525  0.481818      4

# %%
df2 = pd.read_csv('/content/bmi.csv')

# %%
from sklearn.preprocessing import Normalizer
scaler = Normalizer()
df2[['Height','Weight']] = scaler.fit_transform(df2[['Height','Weight']])
df2
# Out:
#      Gender    Height    Weight  Index
# 0      Male  0.875578  0.483077      4
# 1      Male  0.908381  0.418144      2
# 2    Female  0.859536  0.511075      4
# 3    Female  0.882353  0.470588      3
# 4      Male  0.925448  0.378875      3
# ..      ...       ...       ...    ...
# 495  Female  0.700071  0.714073      5
# 496  Female  0.835527  0.549450      4
# 497  Female  0.719753  0.694230      5
# 498    Male  0.844819  0.535052      5
# 499    Male  0.797227  0.603680      5
#
# [500 rows x 4 columns]

# %%
df3 = pd.read_csv('/content/bmi.csv')

# %%
from sklearn.preprocessing import MaxAbsScaler
scaler = MaxAbsScaler()
df3[['Height','Weight']] = scaler.fit_transform(df3[['Height','Weight']])
df3
# Out:
#      Gender    Height   Weight  Index
# 0      Male  0.874372  0.60000      4
# 1      Male  0.949749  0.54375      2
# 2    Female  0.929648  0.68750      4
# 3    Female  0.979899  0.65000      3
# 4      Male  0.748744  0.38125      3
# ..      ...       ...      ...    ...
# 495  Female  0.753769  0.95625      5
# 496  Female  0.924623  0.75625      4
# 497  Female  0.708543  0.85000      5
# 498    Male  0.753769  0.59375      5
# 499    Male  0.869347  0.81875      5
#
# [500 rows x 4 columns]

# %%
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()
df4 = pd.read_csv('/content/bmi.csv')
df4[['Height','Weight']] = scaler.fit_transform(df4[['Height','Weight']])
df4.head()
# Out:
#    Gender    Height    Weight  Index
# 0    Male  0.125000 -0.178571      4
# 1    Male  0.660714 -0.339286      2
# 2  Female  0.517857  0.071429      4
# 3  Female  0.875000 -0.035714      3
# 4    Male -0.767857 -0.803571      3

# %%
from scipy.stats import chi2_contingency
import seaborn as sns
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
contigency_table = pd.crosstab(tips['sex'],tips['time'])
contigency_table
# Out:
# time    Lunch  Dinner
# sex
# Male       33     124
# Female     35      52

# %%
chi2 , p , _ , _ , = chi2_contingency(contigency_table)
print(f"Chi-square value: {chi2}")
print(f"P-value: {p}")
# Out:
# Chi-square value: 9.343808982970623
# P-value: 0.002237400118075248

# %%
from sklearn.feature_selection import SelectKBest, mutual_info_classif
data = {
    'Feature1': [1, 2, 3, 4, 5],
    'Feature2': ['A', 'B' , 'C' , 'A' , 'B'],
    'Feature3': [0, 1, 1, 0, 1],
    'Target': [0, 1, 1, 0, 1]
}
df = pd.DataFrame(data)
X = df[['Feature1', 'Feature3']]
y = df['Target']
selector = SelectKBest(score_func=mutual_info_classif, k=1)
X_new = selector.fit_transform(X, y)
selected_features_indices = selector.get_support(indices = True)
selected_features = X.columns[selected_features_indices]
print("Selected Features")
print(selected_features)
# Out:
# Selected Features
# Index(['Feature3'], dtype='object')
